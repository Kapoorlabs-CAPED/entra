# %%
from entra import generate_k_distributions, plot_distributions_histogram


n = 5 
vectors_per_class = 10000  

data, labels, distribution_names = generate_k_distributions(n = n, vectors_per_class = vectors_per_class)
dimensions_to_plot = [0, 1, 2] 

plot_distributions_histogram(data, labels, distribution_names, dimensions_to_plot)

# %%
import entra

# %%
dir(entra)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'distributions',
#  'generate_k_distributions',
#  'plot_distributions_histogram']
